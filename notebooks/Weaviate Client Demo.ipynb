# %% [markdown]
# # Weaviate Client Demo

# %%
import json
from ray_retriever.serve.async_weaviate_client import AsyncWeaviateClient

# %% [markdown]
# ## Setup client

# %%
aclient = AsyncWeaviateClient('127.0.0.1', 9001)

# %% [markdown]
# ## Get schema

# %%
schema = await aclient.get_schema('Wikipedia')
print(json.dumps(schema, indent=2))
# Out:
# {
#   "class": "Wikipedia",
#   "description": "Class for Wikipedia",
#   "invertedIndexConfig": {
#     "bm25": {
#       "b": 0.75,
#       "k1": 1.2
#     },
#     "cleanupIntervalSeconds": 60,
#     "stopwords": {
#       "additions": null,
#       "preset": "en",
#       "removals": null
#     }
#   },
#   "multiTenancyConfig": {
#     "enabled": false
#   },
#   "properties": [
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "Text property",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "text",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "The ref_doc_id of the Node",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "ref_doc_id",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "node_info (in JSON)",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "node_info",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "The relationships of the node (in JSON)",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "relationships",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "uri",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "document_id",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "doc_id",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "title",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "source",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "_node_content",
#       "tokenization": "word"
#     },
#     {
#       "dataType": [
#         "text"
#       ],
#       "description": "This property was generated by Weaviate's auto-schema feature on Mon Dec 25 14:25:50 2023",
#       "indexFilterable": true,
#       "indexSearchable": true,
#       "name": "_node_type",
#       "tokenization": "word"
#     }
#   ],
#   "replicationConfig": {
#     "factor": 1
#   },
#   "shardingConfig": {
#     "virtualPerPhysical": 128,
#     "desiredCount": 1,
#     "actualCount": 1,
#     "desiredVirtualCount": 128,
#     "actualVirtualCount": 128,
#     "key": "_id",
#     "strategy": "hash",
#     "function": "murmur3"
#   },
#   "vectorIndexConfig": {
#     "skip": false,
#     "cleanupIntervalSeconds": 300,
#     "maxConnections": 64,
#     "efConstruction": 128,
#     "ef": -1,
#     "dynamicEfMin": 100,
#     "dynamicEfMax": 500,
#     "dynamicEfFactor": 8,
#     "vectorCacheMaxObjects": 1000000000000,
#     "flatSearchCutoff": 40000,
#     "distance": "cosine",
#     "pq": {
#       "enabled": false,
#       "bitCompression": false,
#       "segments": 0,
#       "centroids": 256,
#       "trainingLimit": 100000,
#       "encoder": {
#         "type": "kmeans",
#         "distribution": "log-normal"
#       }
#     }
#   },
#   "vectorIndexType": "hnsw",
#   "vectorizer": "none"
# }

# %% [markdown]
# ## Get properties

# %%
properties = await aclient.get_all_properties('Wikipedia')
print(properties)
# Out:
# ['text', 'ref_doc_id', 'node_info', 'relationships', 'uri', 'document_id', 'doc_id', 'title', 'source', '_node_content', '_node_type']

# %% [markdown]
# ## Get nodes

# %%
all_nodes = await aclient.get_nodes('Wikipedia', 
                                        return_embeddings=False, 
                                        max_result_size=10)
print(len(all_nodes))
print(all_nodes[0])
# Out:
# {'_additional': {'id': '000108f1-3d15-4fd9-a7f1-d25f7440fd90'}, '_node_content': '{"id_": "000108f1-3d15-4fd9-a7f1-d25f7440fd90", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/2010", "title": "2010", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "6b9ca5cd-dea3-416a-ad86-e59a32eda349", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/2010", "title": "2010", "source": "wikipedia-20220301.simple"}, "hash": "9cc5688d98fa29c577b9d7b88a3885ce3c8c6fdcbdffefc236d4af35edd90704", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "df711ca2-9b75-4700-9ee3-209017750884", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/2010", "title": "2010", "source": "wikipedia-20220301.simple"}, "hash": "fcf0cf604e1ef7a90ba0e4f207c66a47f083f7b70f5cfe98ca583eb7369d3ce6", "class_name": "RelatedNodeInfo"}}, "hash": "2fb2d2c4ed3f697aadab4ed5f34ea3e5ceb85a66053c43305c1f0a056ea54be2", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': "2010\nApril \n\n April 3 – South African far-right leader Eugene Terre'Blanche is beaten to death at his farm near Ventersdorp, South Africa.\n April 3 – The African Renaissance Monument opens in Dakar, to mark 50 years of Senegal's independence.\n April 7 – Amidst fierce rioting in Kyrgyzstan, President Kurmanbek Bakiyev flees the capital city, Bishkek by plane to the southern city of Osh; the opposition seizes control of the government, and places former foreign minister Roza Otunbayeva as head of an interim government. She later becomes President on July 3.\n April 10 – Poland's President Lech Kaczynski and his wife Maria are among 96 people killed when their plane crashes in thick fog near Smolensk in western Russia.\n April 14 – A 6.9 magnitude Earthquake strikes Qinghai province in China, killing more than 1000 people.\n April 14 – A volcanic eruption occurs near a glacier (Eyjafjallajokull) in southern Iceland, leading to flooding in the nearby area. The cloud of volcanic ash from the eruption causes air traffic all over Northern and Western Europe to be shut down.\n April 20 – General Reynaldo Bignone, former military ruler of Argentina is sentenced to 25 years in prison, for ordering torture during the military dictatorship.\n April 20 – Deepwater Horizon oil spill: An explosion occurs on the Deepwater Horizon Oil Platform in the Gulf of Mexico, near Louisiana. 11 oil workers are killed, and an oil spill is caused, leading to an environmental disaster.\n April 27 – Panama's former military leader Manuel Noriega is handed over to France by the United States.\n April 27 – Greece's sovereign credit rating is downgraded to junk, four days after its government asked for help in resolving its financial crisis. Stock markets around the world drop.\n\nMay", 'title': '2010', 'uri': 'https://simple.wikipedia.org/wiki/2010'}
# {'_additional': {'id': '000137c0-d088-4aad-9d92-4dafce8087cb'}, '_node_content': '{"id_": "000137c0-d088-4aad-9d92-4dafce8087cb", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Playing%20for%20Pizza", "title": "Playing for Pizza", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "1307ca46-c3db-4150-b652-b0b9046f6bda", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Kansas%20Koyotes", "title": "Kansas Koyotes", "source": "wikipedia-20220301.simple"}, "hash": "b2cf2fa607f5165fe873293fe7bcd2db1387375ebd1b6db23c43f35b0730719a", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "09d8e450-f56c-4b13-8dda-4eee283bd26f", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/The%20Grapes%20of%20Wrath", "title": "The Grapes of Wrath", "source": "wikipedia-20220301.simple"}, "hash": "1f072b7e044155310c649622acb46980d2eb6cc37a66f157e183c1ab8cede367", "class_name": "RelatedNodeInfo"}}, "hash": "335327258fdbb310bdb295f739a7e4c2b2b507c810ae9f352ce13d766a069369", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': "Playing for Pizza\nPlaying for Pizza is a short novel by John Grisham, released on September 25, 2007.\nThe novel is about an American football player who can no longer get work in the National Football League. His agent, as a last resort, signs a deal for him to play for the Parma Panthers, in Parma, Italy. The quarterback's move to a small city in a foreign land leads to a series of cultural misadventures.\n\nOther websites\n Panthers.it Official Site\n Share The Dream with Grisham Official Site\n\n2007 books\n20th-century American novels\nEnglish-language novels", 'title': 'Playing for Pizza', 'uri': 'https://simple.wikipedia.org/wiki/Playing%20for%20Pizza'}
# {'_additional': {'id': '00022f3e-58e8-45cd-b9e2-64deb247a860'}, '_node_content': '{"id_": "00022f3e-58e8-45cd-b9e2-64deb247a860", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/June%2025", "title": "June 25", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "9079b92d-280b-4d8d-a10f-64cda02dc69e", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/June%2025", "title": "June 25", "source": "wikipedia-20220301.simple"}, "hash": "fee17fd02707e129fac6e8095638f17d69ec76f07864aa1e0b6687795af0259d", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "f54083ca-6cfe-4aa4-bc57-f8d85ab07c1c", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/June%2025", "title": "June 25", "source": "wikipedia-20220301.simple"}, "hash": "0ba5d349353843735482b07dbcda76664cf83e1502b243d61fd0f20411774ec9", "class_name": "RelatedNodeInfo"}}, "hash": "8261f398902fa9c5a4b24b2cd4b8e3731c77a54286ca334c043ea972394cf479", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'June 25\n1884  Daniel-Henry Kahnweiler, German art promoter (d. 1979)\n1886  Henry H. Arnold, American general (d. 1950)\n1887  Frigyes Karinthy, Hungarian writer and journalist (d. 1938)\n1887  George Abbott, American playwright, screenwriter, producer, director and actor (d. 1995)\n1894  Hermann Oberth, physicist (d. 1989)\n1896  Alfred Anderson, Scottish centenarian and World War I veteran (d. 2005)\n1900  Marta Abba, Italian actress (d. 1988)\n1900  Louis Mountbatten, 1st Earl Mountbatten of Burma (d. 1979)', 'title': 'June 25', 'uri': 'https://simple.wikipedia.org/wiki/June%2025'}
# {'_additional': {'id': '00027538-274b-4e0e-b805-fdf7badfbccd'}, '_node_content': '{"id_": "00027538-274b-4e0e-b805-fdf7badfbccd", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Band%C5%8D%20prisoner%20of%20war%20camp", "title": "Band\\u014d prisoner of war camp", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "e0422c45-7149-4ebc-9dbf-edc4dedc18ae", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Cynthia%20Ozick", "title": "Cynthia Ozick", "source": "wikipedia-20220301.simple"}, "hash": "918d9eb8ec8bea15d9bea4852c07d0d9e358e95533089589cf21ede7a619b420", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "3e575e42-70d2-4eff-b20b-1734338f5983", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/MOD%20%28Marehan%2C%20Ogaden%2C%20Darawiish%29", "title": "MOD (Marehan, Ogaden, Darawiish)", "source": "wikipedia-20220301.simple"}, "hash": "499b70fa78040485c6ca4f1edfd93c58894c90db2885a97a40ac9860207b193d", "class_name": "RelatedNodeInfo"}}, "hash": "6dddbbb924c2b33089002c6d5c222ad59ce562954c2cce760a843f4353cf100c", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': "Bandō prisoner of war camp\nBandō prisoner of war camp was a prisoner of war camp that existed from 1917 to 1920, during and shortly after the First World War. It was located in the city with the same name. It housed about 1000 of the 3900 prisoners of war captured at Tsingtao, China, in 1914. Today, the camp is considered special, because of the liberal rules it had. Many of the prisoners were not professional soldiers, but had other jobs before the war. The commander of the camp, Matsue Toyohisa, saw this, and allowed the prisoners many liberties. One of these liberties was that they were allowed to follow courses to improve their skills. That way, Hermann Richard Hansen directed a choir and an orchestra of prisoners, to perform Beethoven's 9th symphony. This was the first performance of the symphony in Japan and in Asia. When the camp closed in 1920, 63 people chose to stay in Japan.\n\nReferences\n\nHistory of Japan\nWorld War I", 'title': 'Bandō prisoner of war camp', 'uri': 'https://simple.wikipedia.org/wiki/Band%C5%8D%20prisoner%20of%20war%20camp'}
# {'_additional': {'id': '0002c349-b93e-4970-b36c-4c2577bf72ed'}, '_node_content': '{"id_": "0002c349-b93e-4970-b36c-4c2577bf72ed", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Hiromasa%20Yamamoto", "title": "Hiromasa Yamamoto", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "fcb35953-f877-40fc-9b5f-2e9317a28adf", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Hiromasa%20Yamamoto", "title": "Hiromasa Yamamoto", "source": "wikipedia-20220301.simple"}, "hash": "c5f82eed1c6a03506805a9febfdccba09ca49119717e38a22adc09e892a73602", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "2b05f135-5ef7-47bc-97a5-9eccfb505881", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Jorginho%20Putinatti", "title": "Jorginho Putinatti", "source": "wikipedia-20220301.simple"}, "hash": "ea25822e4da8e75554de9d1e34346ec90a99fecc8b724d666d0535573c5f2bbb", "class_name": "RelatedNodeInfo"}}, "hash": "87f41e7a83d940c581bd3213a0eb95d6780dc4ce054afda22abe4d3793310b28", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'Hiromasa Yamamoto\nReferences\n\n1979 births\nLiving people\nFootballers from Aichi Prefecture', 'title': 'Hiromasa Yamamoto', 'uri': 'https://simple.wikipedia.org/wiki/Hiromasa%20Yamamoto'}
# {'_additional': {'id': '0002c68f-cb59-4295-bcd1-7ea45a6de1b2'}, '_node_content': '{"id_": "0002c68f-cb59-4295-bcd1-7ea45a6de1b2", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Science%20Museum%20%28London%29", "title": "Science Museum (London)", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "8eab94c2-1344-456f-8510-2c76d9368450", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Vinessa%20Shaw", "title": "Vinessa Shaw", "source": "wikipedia-20220301.simple"}, "hash": "4e6b5299db3216d0fda75fa1b580c67b96ee72e925426e260b095fc5d8e4e222", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "5f3b99a6-21e3-4616-8293-0fd051ec5e79", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Science%20Museum%20%28London%29", "title": "Science Museum (London)", "source": "wikipedia-20220301.simple"}, "hash": "9eafb1691ac98cf91c78b66789e7b974caf5598334083ec6a5915599be615eff", "class_name": "RelatedNodeInfo"}}, "hash": "db178bbd7a52c945f90e82125442e070dbb0362413e2a684685635f3826147a4", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'Science Museum (London)\nThe Science Museum is one of the three large museums on Exhibition Road, London. It is part of the National Museum of Science and Industry. The museum is a big tourist attraction in London. The science museum is a great place.\n\nIt has been free to enter the Science Museum since 1 December 2001. This is because it is paid for by the government. People may have to pay to enter the temporary exhibitions.\n\nStart and history\nBennet Woodcroft started a museum in 1857. He used items from the Royal Society of Arts and the Great Exhibition. It included some machinery which became the Museum of Patents in 1858, and the Patent Office Museum in 1863. In 1883, the things held in the Patent Office Museum were moved to the South Kensington Museum. In 1885, the Science Collections were renamed the Science Museum. In 1893, the Science Museum got a separate leader. The Art Collections were renamed the Art Museum, which later became the Victoria and Albert Museum.\n\nWhen Queen Victoria laid the foundation stone for the new building for the Art Museum, she said that the museum must be renamed after herself and her dead husband. The whole museum was named after them, but when that new building opened ten years later, the name was only for the Art Collections and the Science Collections were renamed. On June 26, 1909 the Science Museum, as an independent entity, came into existence. The Science Museum’s home today, designed by Sir Richard Allison, were opened to the public over time between 1919–28. This building was known as the East Block, building of which began in 1913 and was stopped during World War I. As the name suggests it was intended to be the first building of a much larger project, which was never made.\n\nCollections\n\nAlthough called a museum of science, it is really more a museum of industry. It has working models and real equipment from the industrial revolution in the 18th century, the great Victorian engineering, the age of aeroplanes and space in the 20th century.', 'title': 'Science Museum (London)', 'uri': 'https://simple.wikipedia.org/wiki/Science%20Museum%20%28London%29'}
# {'_additional': {'id': '0002cc22-26a1-4caa-a0f7-a04c4e288b7d'}, '_node_content': '{"id_": "0002cc22-26a1-4caa-a0f7-a04c4e288b7d", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/I%27m%20Your%20Baby%20Tonight%20%28song%29", "title": "I\'m Your Baby Tonight (song)", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "96c6e5f7-208a-4c58-8d6f-77d20d0cff73", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Muchacha%20italiana%20viene%20a%20casarse", "title": "Muchacha italiana viene a casarse", "source": "wikipedia-20220301.simple"}, "hash": "3970f93d88e60e3ef6dcd4370e53b4b1fcecaf66b77bb6987fc92ec9251a4a64", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "1e3b59b2-1c6d-441f-8663-28d140a1d2fb", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Tierra%20de%20reyes", "title": "Tierra de reyes", "source": "wikipedia-20220301.simple"}, "hash": "753ebccf2489f1f281467dc9f3309cf92366f16f4e30b279ffc4f9dd10f2d5f0", "class_name": "RelatedNodeInfo"}}, "hash": "d0fa132b1a45b1b50f7c388addd42bc8e5365f634e7cdad5f0a4b28612dac3ce", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'I\'m Your Baby Tonight (song)\n"I\'m Your Baby Tonight" was the lead single and title track from Whitney Houston\'s album of the same name. The song became a major hit for Houston. It reached the Top 10 in many countries. It hit #1 on the U.S. Billboard Hot 100.\n\nAfter her death in 2012, the song was ranked at number 18 by Entertainment Weekly.\n\nReferences\n\n1990 songs\nPop songs\nR&B songs\nWhitney Houston songs', 'title': "I'm Your Baby Tonight (song)", 'uri': 'https://simple.wikipedia.org/wiki/I%27m%20Your%20Baby%20Tonight%20%28song%29'}
# {'_additional': {'id': '00033560-46e3-49a8-902d-d5743767cf7c'}, '_node_content': '{"id_": "00033560-46e3-49a8-902d-d5743767cf7c", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Live%20CD", "title": "Live CD", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "a598dd9c-8404-464b-981f-64c22c970e9d", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Live%20CD", "title": "Live CD", "source": "wikipedia-20220301.simple"}, "hash": "23db2188a9fb98b5e50d8d92f50447673ad9a209fa3c08c7ae27c68b0b9c5d61", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "26306381-fb60-4033-9caa-faaee0e252e8", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/PSV%20Eindhoven", "title": "PSV Eindhoven", "source": "wikipedia-20220301.simple"}, "hash": "eb6655e2f1d1c137d160bb0b3a7603128828541c57d106236cfa29802a5648c8", "class_name": "RelatedNodeInfo"}}, "hash": "d41cdfacb82fed831ef4c7500565cb86d58189b6c63fa52080ee0215bd86af35", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'Live CD\nScreenshots \nHere are some images/screenshots of live CDs:\n\nRelated pages\n remastersys, a simple tool to create a customized ubuntu Live CD/DVD\n List of Linux distributions\n\nOther websites \n FreeBSD LiveCD\n Linux Live scripts\n Build your own Custom Live CD\n Bootable CDROM HowTo\n LiveDistro.org: Extensive build/remaster howtos, tools and release announcements.\n Guide: Howto remaster a sidux live CD\n The Live CD List links & information on over 300 Live CDs\n Long list of LiveCDs at the Knoppix Wiki\n The magic of live CDs  Article published on Free Software Magazine about LiveDistros\n Live CD News\n Live CD Build Scripts \n Pondering Live CDs - A BSD perspective on the concept of Live CDs \n Darknet 10 Best Security Live CD Distros for pen-test, forensics, and recovery', 'title': 'Live CD', 'uri': 'https://simple.wikipedia.org/wiki/Live%20CD'}
# {'_additional': {'id': '00035db5-f138-4f53-92fc-2190f6596b33'}, '_node_content': '{"id_": "00035db5-f138-4f53-92fc-2190f6596b33", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Chadwell%20Heath", "title": "Chadwell Heath", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "15390f4c-aa69-45e2-9a7f-92603e47f0d2", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Voice%20of%20America%20Persian%20News%20Network", "title": "Voice of America Persian News Network", "source": "wikipedia-20220301.simple"}, "hash": "ae47d8fbb6265cd8f6732e7defc550d6d9457cb4e31d3adb20c92f4ebaaea02d", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "3417ef71-33c2-4081-b6e5-430ee2b0b7c5", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Petro%20Poroshenko", "title": "Petro Poroshenko", "source": "wikipedia-20220301.simple"}, "hash": "4c24098eee066486810dca01efe593e505d29c45ba325bb8766bf1ad8a989313", "class_name": "RelatedNodeInfo"}}, "hash": "ff829d679519ef0bba89aae7bdf7e5fa6c3b214fef317dab3c21c079df220dc5", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'Chadwell Heath\nChadwell Heath is a suburban area in north-east London. Its postcode is RM6. It is partly in the London Borough of Barking and Dagenham and partly in the London Borough of Redbridge. \n\nAreas of London\nLondon Borough of Barking and Dagenham\nLondon Borough of Redbridge', 'title': 'Chadwell Heath', 'uri': 'https://simple.wikipedia.org/wiki/Chadwell%20Heath'}
# {'_additional': {'id': '00036038-0567-44ec-bf20-6ce5fa41a45e'}, '_node_content': '{"id_": "00036038-0567-44ec-bf20-6ce5fa41a45e", "embedding": null, "metadata": {"uri": "https://simple.wikipedia.org/wiki/Group%208%20element", "title": "Group 8 element", "source": "wikipedia-20220301.simple"}, "excluded_embed_metadata_keys": [], "excluded_llm_metadata_keys": [], "relationships": {"2": {"node_id": "7fdf9f89-8209-42ba-bc9b-5d5878e0064e", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Royal%20Belgian%20Football%20Association", "title": "Royal Belgian Football Association", "source": "wikipedia-20220301.simple"}, "hash": "191e6159b78d5330e375f9ed83e919a0aa251c95ec3cedbb661e0a3e8c677b3c", "class_name": "RelatedNodeInfo"}, "3": {"node_id": "02e3e8ba-da1e-49e2-8473-24276a9a0470", "node_type": "4", "metadata": {"uri": "https://simple.wikipedia.org/wiki/Jacques%20Lambinon", "title": "Jacques Lambinon", "source": "wikipedia-20220301.simple"}, "hash": "23f43cd5f8fb4ad49d80ef654067ef54f150655802c5501612031299240f8fe9", "class_name": "RelatedNodeInfo"}}, "hash": "52f4a77352afa7fb3c2cef74b49ce326e07a34cfc155e152f54d981a12e8139f", "text": "", "start_char_idx": null, "end_char_idx": null, "text_template": "{metadata_str}\\n\\n{content}", "metadata_template": "{key}: {value}", "metadata_seperator": "\\n", "class_name": "Document"}', '_node_type': 'Document', 'doc_id': 'None', 'document_id': 'None', 'node_info': None, 'ref_doc_id': 'None', 'relationships': None, 'source': 'wikipedia-20220301.simple', 'text': 'Group 8 element\nGroup 8 is a group of elements in the periodic table.\n\nGroup 8 has iron (Fe), ruthenium (Ru), osmium (Os) and hassium (Hs).\n\nGroup 8 is in the transition metals section.\n\nPeriodic table\nTransition metals', 'title': 'Group 8 element', 'uri': 'https://simple.wikipedia.org/wiki/Group%208%20element'}
# 10
# id='000108f1-3d15-4fd9-a7f1-d25f7440fd90' index_name='Wikipedia' metadata={'uri': 'https://simple.wikipedia.org/wiki/2010', 'title': '2010', 'source': 'wikipedia-20220301.simple'} text="2010\nApril \n\n April 3 – South African far-right leader Eugene Terre'Blanche is beaten to death at his farm near Ventersdorp, South Africa.\n April 3 – The African Renaissance Monument opens in Dakar, to mark 50 years of Senegal's independence.\n April 7 – Amidst fierce rioting in Kyrgyzstan, President Kurmanbek Bakiyev flees the capital city, Bishkek by plane to the southern city of Osh; the opposition seizes control of the government, and places former foreign minister Roza Otunbayeva as head of an interim government. She later becomes President on July 3.\n April 10 – Poland's President Lech Kaczynski and his wife Maria are among 96 people killed when their plane crashes in thick fog near Smolensk in western Russia.\n April 14 – A 6.9 magnitude Earthquake strikes Qinghai province in China, killing more than 1000 people.\n April 14 – A volcanic eruption occurs near a glacier (Eyjafjallajokull) in southern Iceland, leading to flooding in the nearby area. The cloud of volcanic ash from the eruption causes air traffic all over Northern and Western Europe to be shut down.\n April 20 – General Reynaldo Bignone, former military ruler of Argentina is sentenced to 25 years in prison, for ordering torture during the military dictatorship.\n April 20 – Deepwater Horizon oil spill: An explosion occurs on the Deepwater Horizon Oil Platform in the Gulf of Mexico, near Louisiana. 11 oil workers are killed, and an oil spill is caused, leading to an environmental disaster.\n April 27 – Panama's former military leader Manuel Noriega is handed over to France by the United States.\n April 27 – Greece's sovereign credit rating is downgraded to junk, four days after its government asked for help in resolving its financial crisis. Stock markets around the world drop.\n\nMay" embedding=None

# %% [markdown]
# ## Filter nodes by title

# %%
filter = {
    "path": "title",
    "operator": "Equal",
    "valueText": 'Alan Turing'
}

nodes = await aclient.get_nodes('Wikipedia', 
                                                filter=filter, 
                                                max_result_size=50)
for node in nodes:
    print(f"{node.id}:\n{node.metadata}")
# Out:
# 91183fe4-0e0c-4985-a8ba-e49e20a5749c:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}
# 7c6aaa1c-ea23-47b8-962a-b3514f1939f7:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}
# 8b5a2b43-7178-4bab-906e-f72c099640ac:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}

# %% [markdown]
# ## Filter by like operator
# **TODO** Lookup semantic of like operator

# %%
filter = {
    "path": "title",
    "operator": "Like",
    "valueText": 'Alan'
}

nodes = await aclient.get_nodes('Wikipedia', 
                                filter=filter, 
                                max_result_size=10)
for node in nodes:
    print(f"{node.id}: {node.metadata['title']}")
# Out:
# cfd08cf8-f654-47c0-ac26-a7713af0cbd4: Alan Burgess (cricketer)
# 6d5276f6-8bac-4bdb-a796-0faf4e5fa023: Alan Winde
# 3f62bd0b-2e70-41d6-b552-05a6ded666d2: Alan Metter
# ee233f8f-b205-40ef-a39b-7462f5b99b2d: Alan Walker
# 8c5ef1e4-128a-470a-a1c4-55eb20a111cd: Alan Walker
# 9976d4cf-7bf1-4a03-a36e-e8bc5aeeb3cc: Alan Watts
# 1a198c96-e582-4730-8dc5-0e8d7a1f6b41: Alan S. Becker
# 9810d918-498b-49c3-9c87-ee0b8796c610: Alan Garner (footballer)
# e1d27afe-c443-415f-87c6-29e9ce6c43d5: Alan Minter
# 7028b85c-4d41-49ab-a009-05446561b687: Alan Abraham

# %% [markdown]
# ## Filter nodes by ID

# %%
filter = {
    "path": "id",
    "operator": "Equal",
    "valueText": "91183fe4-0e0c-4985-a8ba-e49e20a5749c"
}

nodes = await aclient.get_nodes('Wikipedia', 
                                    filter=filter, 
                                    max_result_size=10, 
                                    return_embeddings=True)
for node in nodes:
    print(f"{node.id}:\n{node.metadata}")
# Out:
# 91183fe4-0e0c-4985-a8ba-e49e20a5749c:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}

# %% [markdown]
# ## Get nodes by similarity

# %%
# Fetch 'Alan Turing' nodes
filter = {
    "path": "title",
    "operator": "Equal",
    "valueText": 'Alan Turing'
}
alan_turing_nodes = await aclient.get_nodes('Wikipedia', 
                                                filter=filter,
                                                return_embeddings=True,
                                                max_result_size=50)
assert len(alan_turing_nodes) > 0


# Take one of the 'Alan Turing' nodes and find similar nodes. The expectation 
# that the other 'Alan Turing' nodes show up at the top of the result.

query_result = await aclient.find_similar_nodes('Wikipedia',
                                                 alan_turing_nodes[0].embedding, 
                                                 similarity_top_k=10)
for node, similarity in zip(query_result.nodes, query_result.similarities):
    print(f"{node.id}:\n{node.metadata}\n{round(similarity,4)}")
# Out:
# 91183fe4-0e0c-4985-a8ba-e49e20a5749c:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}
# 1.0
# 8b5a2b43-7178-4bab-906e-f72c099640ac:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}
# 0.8406
# 7c6aaa1c-ea23-47b8-962a-b3514f1939f7:
# {'uri': 'https://simple.wikipedia.org/wiki/Alan%20Turing', 'title': 'Alan Turing', 'source': 'wikipedia-20220301.simple'}
# 0.8144
# 7aa6a9fd-1a88-4fab-a6d3-45e7284a488a:
# {'uri': 'https://simple.wikipedia.org/wiki/Homosexuality', 'title': 'Homosexuality', 'source': 'wikipedia-20220301.simple'}
# 0.6191
# 55927f47-2dd5-4138-bc1b-cb1730c0461c:
# {'uri': 'https://simple.wikipedia.org/wiki/Conway%20Berners-Lee', 'title': 'Conway Berners-Lee', 'source': 'wikipedia-20220301.simple'}
# 0.5859
# fd8751bb-2ae0-497e-b1e2-53211c28f9d4:
# {'uri': 'https://simple.wikipedia.org/wiki/Marvin%20Minsky', 'title': 'Marvin Minsky', 'source': 'wikipedia-20220301.simple'}
# 0.5805
# 4d509a79-b64c-4ef2-8e74-6792c83f9c4e:
# {'uri': 'https://simple.wikipedia.org/wiki/Gordon%20Welchman', 'title': 'Gordon Welchman', 'source': 'wikipedia-20220301.simple'}
# 0.5768
# 2ac0d6ee-1d11-476d-9851-a3bfa4dd9208:
# {'uri': 'https://simple.wikipedia.org/wiki/Max%20Newman', 'title': 'Max Newman', 'source': 'wikipedia-20220301.simple'}
# 0.565
# 201974fb-8fcc-45dc-9f78-693b8df9d742:
# {'uri': 'https://simple.wikipedia.org/wiki/Josef%20Mengele', 'title': 'Josef Mengele', 'source': 'wikipedia-20220301.simple'}
# 0.5573
# deddb47a-3341-40c9-b944-f0f365e4f36d:
# {'uri': 'https://simple.wikipedia.org/wiki/Charles%20Bachman', 'title': 'Charles Bachman', 'source': 'wikipedia-20220301.simple'}
# 0.5559
